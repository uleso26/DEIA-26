# %% [markdown]
# # Source Context Demo
#
# This notebook shows the explicit WHO population context tool, the DrugBank and synthetic clinical context tool, and the Q3 workflow that consumes the clinical context output.

# %%
from agents.orchestrator import T2DOrchestrator, bootstrap_runtime
from tools.native_tools import get_clinical_context, get_population_context

bootstrap_runtime()

# %%
get_population_context("United Kingdom")
# Out:
# {'canonical_entities': {'country': 'United Kingdom'},
#  'raw_provenance': {'country': 'United Kingdom', 'top_k': 3},
#  'records': [{'country': 'United Kingdom',
#               'indicator': 'Diabetes prevalence, age-standardized estimate among adults aged 18 '
#                            'years and older',
#               'source_url': 'https://www.who.int/data/gho/data/indicators/indicator-details/GHO/prevalence-of-diabetes-and-obesity-among-adults-aged-18-years-and-older-(age-standardized-estimate)',
#               'unit': 'percent',
#               'value': 5.6,
#               'year': 2021}],
#  'source_metadata': {'storage': 'sqlite', 'table': 'who_gho_diabetes_stats'},
#  'tool_name': 'get_population_context'}

# %%
orchestrator = T2DOrchestrator()
population_response = orchestrator.run_query("What is the diabetes prevalence in the United Kingdom?")
orchestrator.close()
population_response
# Out:
# {'answer': 'Population context indicates adult diabetes prevalence in United Kingdom was 5.6 '
#            'percent in 2021.',
#  'caveats': ['Population statistics are surveillance context and may not generalize to a specific '
#              'clinical cohort.',
#              'Evidence summaries should state recency, publication venue, and evidence type.'],
#  'citations': [{'evidence_tier': 'Tier 2',
#                 'published_at': '2021',
#                 'reference_id': 'WHO:United Kingdom:2021',
#                 'source': 'WHO GHO',
#                 'title': 'Diabetes prevalence, age-standardized estimate among adults aged 18 '
#                          'years and older',
#                 'url': 'https://www.who.int/data/gho/data/indicators/indicator-details/GHO/prevalence-of-diabetes-and-obesity-among-adults-aged-18-years-and-older-(age-standardized-estimate)'}],
#  'evidence_tiers': ['Tier 2'],
#  'metadata': {'mode': 'population_context',
#               'population_context_used': True,
#               'query': 'What is the diabetes prevalence in the United Kingdom?',
#               'question_class_name': 'Literature And Population Evidence',
#               'route_reason': 'enterprise_core',
#               'routing_mode': 'deterministic',
#               'scope_family': 'enterprise_core',
#               'synthesis_mode': 'deterministic'},
#  'question_class': 'Q6',
#  'sections': [{'agent': 'Literature Agent',
#                'caveats': ['Population statistics are surveillance context and may not generalize '
#                            'to a specific clinical cohort.',
#                            'Evidence summaries should state recency, publication venue, and '
#                            'evidence type.'],
#                'citations': [{'evidence_tier': 'Tier 2',
#                               'published_at': '2021',
#                               'reference_id': 'WHO:United Kingdom:2021',
#                               'source': 'WHO GHO',
#                               'title': 'Diabetes prevalence, age-standardized estimate among '
#                                        'adults aged 18 years and older',
#                               'url': 'https://www.who.int/data/gho/data/indicators/indicator-details/GHO/prevalence-of-diabetes-and-obesity-among-adults-aged-18-years-and-older-(age-standardized-estimate)'}],
#                'evidence_tiers': ['Tier 2'],
#                'metadata': {'mode': 'population_context', 'population_context_used': True},
#                'question_class': 'Q6',
#                'summary': 'Population context indicates adult diabetes prevalence in United '
#                           'Kingdom was 5.6 percent in 2021.',
#                'tool_outputs': [{'canonical_entities': {'country': 'United Kingdom'},
#                                  'raw_provenance': {'country': 'United Kingdom', 'top_k': 1},
#                                  'records': [{'country': 'United Kingdom',
#                                               'indicator': 'Diabetes prevalence, age-standardized '
#                                                            'estimate among adults aged 18 years '
#                                                            'and older',
#                                               'source_url': 'https://www.who.int/data/gho/data/indicators/indicator-details/GHO/prevalence-of-diabetes-and-obesity-among-adults-aged-18-years-and-older-(age-standardized-estimate)',
#                                               'unit': 'percent',
#                                               'value': 5.6,
#                                               'year': 2021}],
#                                  'source_metadata': {'storage': 'sqlite',
#                                                      'table': 'who_gho_diabetes_stats'},
#                                  'tool_name': 'get_population_context'}]}],
#  'trace_id': 'trace-42fba234ca64'}

# %%
get_clinical_context("ADA pathway after metformin for obesity GLP-1 receptor agonist")
# Out:
# {'canonical_entities': {'drugs': []},
#  'raw_provenance': {'class_hints': ['glp-1 receptor agonist'],
#                     'phenotype_terms': ['obesity', 'metformin'],
#                     'query': 'ADA pathway after metformin for obesity GLP-1 receptor agonist'},
#  'records': [{'canonical_drug': 'semaglutide',
#               'drug_class': 'GLP-1 receptor agonist',
#               'drugbank_id': 'DB13928',
#               'interactions': ['insulin', 'sulfonylureas'],
#               'pharmacology': 'Incretin mimetic used for glycemic control and chronic weight '
#                               'management.',
#               'record_type': 'drugbank',
#               'source_url': 'https://go.drugbank.com/'},
#              {'canonical_drug': 'tirzepatide',
#               'drug_class': 'Dual GIP/GLP-1 receptor agonist',
#               'drugbank_id': 'DB15171',
#               'interactions': ['insulin', 'sulfonylureas'],
#               'pharmacology': 'Incretin-based therapy with dual GIP and GLP-1 receptor activity.',
#               'record_type': 'drugbank',
#               'source_url': 'https://go.drugbank.com/'},
#              {'age_band': '55-64',
#               'bmi_category': 'obesity_class_2',
#               'ckd_stage': 'stage_3',
#               'clinical_priority': 'cardiorenal_protection',
#               'current_therapy': 'metformin',
#               'data_origin': 'synthetic_seed_profile',
#               'heart_failure': False,
#               'match_score': 3,
#               'patient_id': 'SYN001',
#               'record_type': 'synthetic_profile',
#               'sex': 'female'},
#              {'age_band': '45-54',
#               'bmi_category': 'obesity_class_3',
#               'ckd_stage': 'none',
#               'clinical_priority': 'weight_loss',
#               'current_therapy': 'metformin',
#               'data_origin': 'synthetic_seed_profile',
#               'heart_failure': False,
#               'match_score': 3,
#               'patient_id': 'SYN003',
#               'record_type': 'synthetic_profile',
#               'sex': 'female'}],
#  'source_metadata': {'storage': 'sqlite',
#                      'tables': ['drugbank_classifications', 'synthetic_patient_profiles']},
#  'tool_name': 'get_clinical_context'}

# %%
orchestrator = T2DOrchestrator()
response = orchestrator.run_query("ADA pathway after metformin for obesity")
orchestrator.close()
response
# Out:
# {'answer': 'ADA Standards of Care 2025 pathway logic prioritizes GLP-1 receptor agonist after '
#            'metformin for patients matching Type 2 Diabetes, obesity, need_weight_loss. Drug '
#            'reference context aligned this recommendation with GLP-1 receptor agonist options such '
#            'as semaglutide. A matched synthetic cohort profile reflected obesity_class_2 status, '
#            'stage_3, and metformin background. This represents published clinical guideline logic, '
#            'not medical advice.',
#  'caveats': ['This represents published clinical guideline logic, not medical advice.',
#              'Synthetic patient profiles are illustrative internal context, not real-world '
#              'evidence.'],
#  'citations': [{'evidence_tier': 'Tier 1',
#                 'published_at': None,
#                 'reference_id': 'ADA Standards of Care',
#                 'source': 'ADA Standards of Care',
#                 'title': 'ADA Standards of Care 2025',
#                 'url': 'https://diabetesjournals.org/care/issue/48/Supplement_1'},
#                {'evidence_tier': 'Tier 2',
#                 'published_at': None,
#                 'reference_id': 'DB13928',
#                 'source': 'DrugBank',
#                 'title': 'Semaglutide classification',
#                 'url': 'https://go.drugbank.com/'}],
#  'evidence_tiers': ['Tier 1', 'Tier 2'],
#  'metadata': {'clinical_context_used': True,
#               'guideline_mode': 'guideline-informed',
#               'query': 'ADA pathway after metformin for obesity',
#               'question_class_name': 'Guideline And Sequencing Intelligence',
#               'route_reason': 'enterprise_core',
#               'routing_mode': 'deterministic',
#               'scope_family': 'enterprise_core',
#               'synthesis_mode': 'deterministic'},
#  'question_class': 'Q3',
#  'sections': [{'agent': 'Knowledge Graph Agent',
#                'caveats': ['This represents published clinical guideline logic, not medical '
#                            'advice.',
#                            'Synthetic patient profiles are illustrative internal context, not '
#                            'real-world evidence.'],
#                'citations': [{'evidence_tier': 'Tier 1',
#                               'published_at': None,
#                               'reference_id': 'ADA Standards of Care',
#                               'source': 'ADA Standards of Care',
#                               'title': 'ADA Standards of Care 2025',
#                               'url': 'https://diabetesjournals.org/care/issue/48/Supplement_1'},
#                              {'evidence_tier': 'Tier 2',
#                               'published_at': None,
#                               'reference_id': 'DB13928',
#                               'source': 'DrugBank',
#                               'title': 'Semaglutide classification',
#                               'url': 'https://go.drugbank.com/'}],
#                'evidence_tiers': ['Tier 1', 'Tier 2'],
#                'metadata': {'clinical_context_used': True, 'guideline_mode': 'guideline-informed'},
#                'question_class': 'Q3',
#                'summary': 'ADA Standards of Care 2025 pathway logic prioritizes GLP-1 receptor '
#                           'agonist after metformin for patients matching Type 2 Diabetes, obesity, '
#                           'need_weight_loss. Drug reference context aligned this recommendation '
#                           'with GLP-1 receptor agonist options such as semaglutide. A matched '
#                           'synthetic cohort profile reflected obesity_class_2 status, stage_3, and '
#                           'metformin background.',
#                'tool_outputs': [{'canonical_entities': {'drug': {'canonical_id': 'metformin'}},
#                                  'raw_provenance': {'comorbidity': 'obesity',
#                                                     'guideline_hint': 'ADA',
#                                                     'phenotype_terms': ['obesity'],
#                                                     'start_drug': 'metformin'},
#                                  'records': [{'conditions': ['Type 2 Diabetes',
#                                                              'obesity',
#                                                              'need_weight_loss'],
#                                               'guideline_name': 'ADA Standards of Care',
#                                               'guideline_url': 'https://diabetesjournals.org/care/issue/48/Supplement_1',
#                                               'guideline_version': '2025',
#                                               'next_step': 'GLP-1 receptor agonist',
#                                               'ordinal': 1,
#                                               'rationale': 'Consider GLP-1 receptor agonists when '
#                                                            'additional weight loss or cardiorenal '
#                                                            'benefit is desired.',
#                                               'score': 8}],
#                                  'requested_at': '2026-04-01T00:08:42+00:00',
#                                  'server_name': 'knowledge-mcp-server',
#                                  'source_metadata': {'fallback_reason': 'live_query_returned_no_pathway_records',
#                                                      'graph_file': 'data/processed/neo4j_graph.json',
#                                                      'storage': 'neo4j_fallback'},
#                                  'tool_name': 'query_pathway'},
#                                 {'canonical_entities': {'drugs': []},
#                                  'raw_provenance': {'class_hints': ['glp-1 receptor agonist'],
#                                                     'phenotype_terms': ['obesity', 'metformin'],
#                                                     'query': 'ADA pathway after metformin for '
#                                                              'obesity GLP-1 receptor agonist'},
#                                  'records': [{'canonical_drug': 'semaglutide',
#                                               'drug_class': 'GLP-1 receptor agonist',
#                                               'drugbank_id': 'DB13928',
#                                               'interactions': ['insulin', 'sulfonylureas'],
#                                               'pharmacology': 'Incretin mimetic used for glycemic '
#                                                               'control and chronic weight '
#                                                               'management.',
#                                               'record_type': 'drugbank',
#                                               'source_url': 'https://go.drugbank.com/'},
#                                              {'canonical_drug': 'tirzepatide',
#                                               'drug_class': 'Dual GIP/GLP-1 receptor agonist',
#                                               'drugbank_id': 'DB15171',
#                                               'interactions': ['insulin', 'sulfonylureas'],
#                                               'pharmacology': 'Incretin-based therapy with dual '
#                                                               'GIP and GLP-1 receptor activity.',
#                                               'record_type': 'drugbank',
#                                               'source_url': 'https://go.drugbank.com/'},
#                                              {'age_band': '55-64',
#                                               'bmi_category': 'obesity_class_2',
#                                               'ckd_stage': 'stage_3',
#                                               'clinical_priority': 'cardiorenal_protection',
#                                               'current_therapy': 'metformin',
#                                               'data_origin': 'synthetic_seed_profile',
#                                               'heart_failure': False,
#                                               'match_score': 3,
#                                               'patient_id': 'SYN001',
#                                               'record_type': 'synthetic_profile',
#                                               'sex': 'female'},
#                                              {'age_band': '45-54',
#                                               'bmi_category': 'obesity_class_3',
#                                               'ckd_stage': 'none',
#                                               'clinical_priority': 'weight_loss',
#                                               'current_therapy': 'metformin',
#                                               'data_origin': 'synthetic_seed_profile',
#                                               'heart_failure': False,
#                                               'match_score': 3,
#                                               'patient_id': 'SYN003',
#                                               'record_type': 'synthetic_profile',
#                                               'sex': 'female'}],
#                                  'source_metadata': {'storage': 'sqlite',
#                                                      'tables': ['drugbank_classifications',
#                                                                 'synthetic_patient_profiles']},
#                                  'tool_name': 'get_clinical_context'}]}],
#  'trace_id': 'trace-f9115ebc0033'}
